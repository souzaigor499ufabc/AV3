# %% [markdown]
# ![alt text]({8059FFB0-1405-4ABD-924B-7FBB1F931805}.png)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("WB_HLO.csv")
df
# Out:
#           STRUCTURE                STRUCTURE_ID ACTION FREQ_ID FREQ_NAME  \
# 0     datastructure  WB.DATA360:DS_DATA360(1.1)      I       A    Annual
# 1     datastructure  WB.DATA360:DS_DATA360(1.1)      I       A    Annual
# 2     datastructure  WB.DATA360:DS_DATA360(1.1)      I       A    Annual
# 3     datastructure  WB.DATA360:DS_DATA360(1.1)      I       A    Annual
# 4     datastructure  WB.DATA360:DS_DATA360(1.1)      I       A    Annual
# ...             ...                         ...    ...     ...       ...
# 6064  datastructure  WB.DATA360:DS_DATA360(1.1)      I       A    Annual
# 6065  datastructure  WB.DATA360:DS_DATA360(1.1)      I       A    Annual
# 6066  datastructure  WB.DATA360:DS_DATA360(1.1)      I       A    Annual
# 6067  datastructure  WB.DATA360:DS_DATA360(1.1)      I       A    Annual
# 6068  datastructure  WB.DATA360:DS_DATA360(1.1)      I       A    Annual
#
#      REF_AREA_ID REF_AREA_NAME INDICATOR_ID  \
# 0            AFG   Afghanistan    WB_HLO_SE
# ...

# %%
df.shape
# Out:
# (15039, 33)

# %%
df_BRA = df[df["REF_AREA"] == "BRA"]

# %%
df
# Out:
#            STRUCTURE                STRUCTURE_ID ACTION FREQ FREQ_LABEL  \
# 0      datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 1      datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 2      datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 3      datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 4      datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# ...              ...                         ...    ...  ...        ...
# 15034  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 15035  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 15036  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 15037  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
# 15038  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual
#
#       REF_AREA       REF_AREA_LABEL    INDICATOR         INDICATOR_LABEL SEX  \
# ...

# %%
for _, row in df_BRA.iterrows():
    print(row["REF_AREA"], row["OBS_VALUE"], row["TIME_PERIOD"])
# Out:
# BRA 0.8433172106742859 2010
# BRA 0.857953667640686 2018
# BRA 0.8613823652267456 2020
# BRA 0.7909870147705078 2010
# BRA 0.8091695308685303 2018
# BRA 0.8137748837471008 2020
# BRA 0.8964285254478455 2010
# BRA 0.9074544310569764 2018
# BRA 0.9097042083740234 2020
# BRA 11.538148880004885 2010
# BRA 11.907047271728516 2018
# BRA 11.907047271728516 2020
# BRA nan 2010
# BRA nan 2018
# BRA nan 2020
# BRA nan 2010
# BRA nan 2018
# BRA nan 2020
# BRA 0.5329524874687195 2010
# BRA 0.5457237362861633 2018
# BRA 0.5514979362487793 2020
# BRA nan 2010
# BRA nan 2018
# BRA nan 2020
# BRA nan 2010
# BRA nan 2018
# BRA nan 2020
# BRA 0.5284226536750793 2010
# BRA 0.5401515960693359 2018
# BRA 0.5463635325431824 2020
# BRA nan 2010
# BRA nan 2018
# BRA nan 2020
# BRA nan 2010
# BRA nan 2018
# BRA nan 2020
# BRA 0.5373899936676025 2010
# BRA 0.5512616038322449 2018
# BRA 0.5563690662384033 2020
# BRA nan 2010
# BRA nan 2018
# BRA nan 2020
# BRA nan 2010
# BRA nan 2018
# BRA nan 2020
# ...
